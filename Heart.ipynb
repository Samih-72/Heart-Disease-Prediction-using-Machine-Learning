# %%
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# eda

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 97.6 KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df['HeartDisease'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde=True)
plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)
plt.tight_layout()

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 223     10
# 220     10
# 211      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
ch_mean=df.loc[df['Cholesterol'] !=0,'Cholesterol'].mean()

# %%
ch_mean
# Out:
# np.float64(244.6353887399464)

# %%
df['Cholesterol']=df['Cholesterol'].replace(0,ch_mean)

# %%
df['Cholesterol']=df['Cholesterol'].round(2)

# %%
df['Cholesterol']
# Out:
# 0      289.0
# 1      180.0
# 2      283.0
# 3      214.0
# 4      195.0
#        ...
# 913    264.0
# 914    193.0
# 915    131.0
# 916    236.0
# 917    175.0
# Name: Cholesterol, Length: 918, dtype: float64

# %%
restingbp_mean=df.loc[df['RestingBP']!=0,'RestingBP'].mean()

# %%
df['RestingBP']= df['RestingBP'].replace(0,restingbp_mean)

# %%
df['RestingBP']=df['RestingBP'].round(2)

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde=True)
plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)
plt.tight_layout()

# %%
sns.countplot(x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=df['ChestPainType'],hue =df['HeartDisease'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x=df['FastingBS'],hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
df['FastingBS'].value_counts()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64

# %%
sns.boxplot(x='HeartDisease',y='Cholesterol',data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x='HeartDisease',y='Age',data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# datapreprocessing and data cleaning

# %%
df_encode=pd.get_dummies(df,drop_first=True)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40      140.0        289.0          0    172      0.0             0
# 1     49      160.0        180.0          0    156      1.0             1
# 2     37      130.0        283.0          0     98      0.0             0
# 3     48      138.0        214.0          0    108      1.5             1
# 4     54      150.0        195.0          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45      110.0        264.0          0    132      1.2             1
# 914   68      144.0        193.0          1    141      3.4             1
# 915   57      130.0        131.0          0    115      1.2             1
# 916   57      130.0        236.0          0    174      0.0             1
# 917   38      138.0        175.0          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0     True               True              False             False
# 1    False              False               True             False
# 2     True               True              False             False
# 3    False              False              False             False
# 4     True              False               True             False
# ..     ...                ...                ...               ...
# 913   True              False              False              True
# 914   True              False              False             False
# 915   True              False              False             False
# 916  False               True              False             False
# 917   True              False               True             False
#
#      RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# 0                 True          False             False          False
# 1                 True          False             False           True
# 2                False           True             False          False
# 3                 True          False              True           True
# 4                 True          False             False          False
# ..                 ...            ...               ...            ...
# 913               True          False             False           True
# 914               True          False             False           True
# 915               True          False              True           True
# 916              False          False             False           True
# 917               True          False             False          False
#
#      ST_Slope_Up
# 0           True
# 1          False
# 2           True
# 3          False
# 4           True
# ..           ...
# 913        False
# 914        False
# 915        False
# 916        False
# 917         True
#
# [918 rows x 16 columns]

# %%
df_encode=df_encode.astype(int)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0        1                  1                  0                 0
# 1        0                  0                  1                 0
# 2        1                  1                  0                 0
# 3        0                  0                  0                 0
# 4        1                  0                  1                 0
# ..     ...                ...                ...               ...
# 913      1                  0                  0                 1
# 914      1                  0                  0                 0
# 915      1                  0                  0                 0
# 916      0                  1                  0                 0
# 917      1                  0                  1                 0
#
#      RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# 0                    1              0                 0              0
# 1                    1              0                 0              1
# 2                    0              1                 0              0
# 3                    1              0                 1              1
# 4                    1              0                 0              0
# ..                 ...            ...               ...            ...
# 913                  1              0                 0              1
# 914                  1              0                 0              1
# 915                  1              0                 1              1
# 916                  0              0                 0              1
# 917                  1              0                 0              0
#
#      ST_Slope_Up
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1
# ..           ...
# 913            0
# 914            0
# 915            0
# 916            0
# 917            1
#
# [918 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler
numerical_cols = [ 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
scaler = StandardScaler()
df_encode[numerical_cols] = scaler.fit_transform(df_encode[numerical_cols])
df_encode.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  HeartDisease  \
# 0   40   0.414885     0.834754          0  1.382928 -0.727592             0
# 1   49   1.527224    -1.210675          0  0.754157  0.282891             1
# 2   37  -0.141284     0.722161          0 -1.525138 -0.727592             0
# 3   48   0.303651    -0.572651          0 -1.132156  0.282891             1
# 4   54   0.971054    -0.929194          0 -0.581981 -0.727592             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# 0                  1              0                 0              0
# 1                  1              0                 0              1
# 2                  0              1                 0              0
# 3                  1              0                 1              1
# 4                  1              0                 0              0
#
#    ST_Slope_Up
# 0            1
# 1            0
# 2            1
# 3            0
# 4            1

# %% [markdown]
# feature extraction and scaling

# %%
df_encode['AgeGroup'] = pd.cut(
    df_encode['Age'],
    bins=[0,40,55,100],
    labels=['Young','Middle','Senior']
)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  HeartDisease  \
# 0     40   0.414885     0.834754          0  1.382928 -0.727592             0
# 1     49   1.527224    -1.210675          0  0.754157  0.282891             1
# 2     37  -0.141284     0.722161          0 -1.525138 -0.727592             0
# 3     48   0.303651    -0.572651          0 -1.132156  0.282891             1
# 4     54   0.971054    -0.929194          0 -0.581981 -0.727592             0
# ..   ...        ...          ...        ...       ...       ...           ...
# 913   45  -1.253622     0.365619          0 -0.188999  0.282891             1
# 914   68   0.637353    -0.966725          1  0.164684  2.303858             1
# 915   57  -0.141284    -2.130180          0 -0.857069  0.282891             1
# 916   57  -0.141284    -0.159813          0  1.461525 -0.727592             1
# 917   38   0.303651    -1.304502          0  1.422226 -0.727592             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0        1                  1                  0                 0
# 1        0                  0                  1                 0
# 2        1                  1                  0                 0
# 3        0                  0                  0                 0
# 4        1                  0                  1                 0
# ..     ...                ...                ...               ...
# 913      1                  0                  0                 1
# 914      1                  0                  0                 0
# 915      1                  0                  0                 0
# 916      0                  1                  0                 0
# 917      1                  0                  1                 0
#
#      RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# 0                    1              0                 0              0
# 1                    1              0                 0              1
# 2                    0              1                 0              0
# 3                    1              0                 1              1
# 4                    1              0                 0              0
# ..                 ...            ...               ...            ...
# 913                  1              0                 0              1
# 914                  1              0                 0              1
# 915                  1              0                 1              1
# 916                  0              0                 0              1
# 917                  1              0                 0              0
#
#      ST_Slope_Up AgeGroup
# 0              1    Young
# 1              0   Middle
# 2              1    Young
# 3              0   Middle
# 4              1   Middle
# ..           ...      ...
# 913            0   Middle
# 914            0   Senior
# 915            0   Senior
# 916            0   Senior
# 917            1    Young
#
# [918 rows x 17 columns]

# %%
df_encode=pd.get_dummies(df_encode, columns=['AgeGroup'], drop_first=True).astype(int)

# %%
df_encode['HighCholesterol'] = (
    df['Cholesterol'] > 240
).astype(int)

# %%
df_encode['LowMaxHR'] = (
    df['MaxHR'] < 100
).astype(int)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40          0            0          0      1        0             0
# 1     49          1           -1          0      0        0             1
# 2     37          0            0          0     -1        0             0
# 3     48          0            0          0     -1        0             1
# 4     54          0            0          0      0        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45         -1            0          0      0        0             1
# 914   68          0            0          1      0        2             1
# 915   57          0           -2          0      0        0             1
# 916   57          0            0          0      1        0             1
# 917   38          0           -1          0      1        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ...  ST_Slope_Flat  \
# 0        1                  1                  0  ...              0
# 1        0                  0                  1  ...              1
# 2        1                  1                  0  ...              0
# 3        0                  0                  0  ...              1
# 4        1                  0                  1  ...              0
# ..     ...                ...                ...  ...            ...
# 913      1                  0                  0  ...              1
# 914      1                  0                  0  ...              1
# 915      1                  0                  0  ...              1
# 916      0                  1                  0  ...              1
# 917      1                  0                  1  ...              0
#
#      ST_Slope_Up  HighCholesterol  LowMaxHR  Age_Cholesterol  Age_BP  \
# 0              1                1         0            11560    5600
# 1              0                0         0             8820    7840
# 2              1                1         1            10471    4810
# 3              0                0         0            10272    6624
# 4              1                0         0            10530    8100
# ..           ...              ...       ...              ...     ...
# 913            0                1         0            11880    4950
# 914            0                0         0            13124    9792
# 915            0                0         0             7467    7410
# 916            0                0         0            13452    7410
# 917            1                0         0             6650    5244
#
#      RiskScore  OldpeakRisk  AgeGroup_Middle  AgeGroup_Senior
# 0            1            0                0                0
# 1            1            0                1                0
# 2            2            0                0                0
# 3            0            0                1                0
# 4            1            0                1                0
# ..         ...          ...              ...              ...
# 913          1            0                1                0
# 914          2            1                0                1
# 915          0            0                0                1
# 916          0            0                0                1
# 917          0            0                0                0
#
# [918 rows x 24 columns]

# %%
df_encode['Age_Cholesterol'] = (
    df['Age'] * df['Cholesterol']
)

# %%
df_encode['Age_BP'] = (
    df['Age'] * df['RestingBP']
)

# %%
df_encode['RiskScore'] = (
    (df['Age'] > 60).astype(int) +
    (df['RestingBP'] > 140).astype(int) +
    (df['Cholesterol'] > 240).astype(int) +
    (df['MaxHR'] < 100).astype(int)
)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40          0            0          0      1        0             0
# 1     49          1           -1          0      0        0             1
# 2     37          0            0          0     -1        0             0
# 3     48          0            0          0     -1        0             1
# 4     54          0            0          0      0        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45         -1            0          0      0        0             1
# 914   68          0            0          1      0        2             1
# 915   57          0           -2          0      0        0             1
# 916   57          0            0          0      1        0             1
# 917   38          0           -1          0      1        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ...  ST_Slope_Flat  \
# 0        1                  1                  0  ...              0
# 1        0                  0                  1  ...              1
# 2        1                  1                  0  ...              0
# 3        0                  0                  0  ...              1
# 4        1                  0                  1  ...              0
# ..     ...                ...                ...  ...            ...
# 913      1                  0                  0  ...              1
# 914      1                  0                  0  ...              1
# 915      1                  0                  0  ...              1
# 916      0                  1                  0  ...              1
# 917      1                  0                  1  ...              0
#
#      ST_Slope_Up  HighCholesterol  LowMaxHR  Age_Cholesterol  Age_BP  \
# 0              1                1         0          11560.0  5600.0
# 1              0                0         0           8820.0  7840.0
# 2              1                1         1          10471.0  4810.0
# 3              0                0         0          10272.0  6624.0
# 4              1                0         0          10530.0  8100.0
# ..           ...              ...       ...              ...     ...
# 913            0                1         0          11880.0  4950.0
# 914            0                0         0          13124.0  9792.0
# 915            0                0         0           7467.0  7410.0
# 916            0                0         0          13452.0  7410.0
# 917            1                0         0           6650.0  5244.0
#
#      RiskScore  OldpeakRisk  AgeGroup_Middle  AgeGroup_Senior
# 0            1            0                0                0
# 1            1            0                1                0
# 2            2            0                0                0
# 3            0            0                1                0
# 4            1            0                1                0
# ..         ...          ...              ...              ...
# 913          1            0                1                0
# 914          2            1                0                1
# 915          0            0                0                1
# 916          0            0                0                1
# 917          0            0                0                0
#
# [918 rows x 24 columns]

# %%
df_encode['OldpeakRisk'] = (
    df['Oldpeak'] > 2
).astype(int)

# %%
corr = df_encode.corr(numeric_only=True)

corr['HeartDisease'].sort_values(
    ascending=False
)
# Out:
# HeartDisease         1.000000
# ST_Slope_Flat        0.554134
# ExerciseAngina_Y     0.494282
# RiskScore            0.320222
# Sex_M                0.305445
# Age                  0.282039
# AgeGroup_Senior      0.274986
# Oldpeak              0.268460
# FastingBS            0.267291
# Age_BP               0.265927
# OldpeakRisk          0.250814
# Age_Cholesterol      0.228842
# HighCholesterol      0.227634
# LowMaxHR             0.161674
# RestingECG_ST        0.102527
# RestingBP            0.089932
# Cholesterol          0.041767
# ChestPainType_TA    -0.054790
# RestingECG_Normal   -0.091580
# AgeGroup_Middle     -0.188566
# ChestPainType_NAP   -0.212964
# MaxHR               -0.331048
# ChestPainType_ATA   -0.401924
# ST_Slope_Up         -0.622164
# Name: HeartDisease, dtype: float64

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40          0            0          0      1        0             0
# 1     49          1           -1          0      0        0             1
# 2     37          0            0          0     -1        0             0
# 3     48          0            0          0     -1        0             1
# 4     54          0            0          0      0        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45         -1            0          0      0        0             1
# 914   68          0            0          1      0        2             1
# 915   57          0           -2          0      0        0             1
# 916   57          0            0          0      1        0             1
# 917   38          0           -1          0      1        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ...  ST_Slope_Flat  \
# 0        1                  1                  0  ...              0
# 1        0                  0                  1  ...              1
# 2        1                  1                  0  ...              0
# 3        0                  0                  0  ...              1
# 4        1                  0                  1  ...              0
# ..     ...                ...                ...  ...            ...
# 913      1                  0                  0  ...              1
# 914      1                  0                  0  ...              1
# 915      1                  0                  0  ...              1
# 916      0                  1                  0  ...              1
# 917      1                  0                  1  ...              0
#
#      ST_Slope_Up  HighCholesterol  LowMaxHR  Age_Cholesterol  Age_BP  \
# 0              1                1         0          11560.0  5600.0
# 1              0                0         0           8820.0  7840.0
# 2              1                1         1          10471.0  4810.0
# 3              0                0         0          10272.0  6624.0
# 4              1                0         0          10530.0  8100.0
# ..           ...              ...       ...              ...     ...
# 913            0                1         0          11880.0  4950.0
# 914            0                0         0          13124.0  9792.0
# 915            0                0         0           7467.0  7410.0
# 916            0                0         0          13452.0  7410.0
# 917            1                0         0           6650.0  5244.0
#
#      RiskScore  OldpeakRisk  AgeGroup_Middle  AgeGroup_Senior
# 0            1            0                0                0
# 1            1            0                1                0
# 2            2            0                0                0
# 3            0            0                1                0
# 4            1            0                1                0
# ..         ...          ...              ...              ...
# 913          1            0                1                0
# 914          2            1                0                1
# 915          0            0                0                1
# 916          0            0                0                1
# 917          0            0                0                0
#
# [918 rows x 24 columns]

# %%
df_encode.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease', 'Sex_M', 'ChestPainType_ATA', 'ChestPainType_NAP',
#        'ChestPainType_TA', 'RestingECG_Normal', 'RestingECG_ST',
#        'ExerciseAngina_Y', 'ST_Slope_Flat', 'ST_Slope_Up', 'HighCholesterol',
#        'LowMaxHR', 'Age_Cholesterol', 'Age_BP', 'RiskScore', 'OldpeakRisk',
#        'AgeGroup_Middle', 'AgeGroup_Senior'],
#       dtype='str')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
X=df_encode.drop('HeartDisease',axis=1)

# %%
y=df_encode['HeartDisease']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier(),
    "SVM (RBF Kernel)": SVC(probability=True)
}

# %%
result= []

# %%
for name,model in models.items():
    model.fit(X_train_scaled,y_train)
    y_pred=model.predict(X_test_scaled)
    acc=accuracy_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)
    result.append({
        'model':name,
        'Accuracy':round(acc,4),
        'f1_score':round(f1,4)
    })

# %%
result
# Out:
# [{'model': 'Logistic Regression', 'Accuracy': 0.8746, 'f1_score': 0.8902},
#  {'model': 'KNN', 'Accuracy': 0.8383, 'f1_score': 0.8604},
#  {'model': 'Naive Bayes', 'Accuracy': 0.8152, 'f1_score': 0.8313},
#  {'model': 'Decision Tree', 'Accuracy': 0.7822, 'f1_score': 0.8092},
#  {'model': 'SVM (RBF Kernel)', 'Accuracy': 0.8614, 'f1_score': 0.8793}]

# %%
import joblib
joblib.dump(models["KNN"],'KNN_heart.pkl')
joblib.dump(scaler,'scaler.pkl')
joblib.dump(X.columns.tolist(),'columns.pkl')
# Out:
# ['columns.pkl']
